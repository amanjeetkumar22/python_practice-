# %% [markdown]
# # Panda Series
# A series is one dimensional labeled array capable of holding any data type. The axis labeled are collectively called the index

# %% [markdown]
# ## creating Series

# %% [markdown]
# .\venv\Scripts\Activate.ps1
# pip install pandas
# pip install numpy

# %%
import numpy as np
import pandas as pd

# %%
label=['a','b','c']
list=[10,20,30]
arr=np.array([4,5,6])
d={1:10,2:20,6:30}

# %%
pd.Series(list,index=arr)
# Out:
# 4    10
# 5    20
# 6    30
# dtype: int64

# %%
pd.Series(d)
# Out:
# 1    10
# 2    20
# 6    30
# dtype: int64

# %% [markdown]
# ### Data Frames
# combination of multiple series

# %% [markdown]
# ### creating of data frame

# %%
data ={
    'Name':['Aman','Panda','Kalu','Mahi','Somya'],
    'Age':[20,21,22,23,24],
    'City':['New York','Paris','Nigga','Swarg'],
    'salary':[100000,20000,30000,40000,50000]
}
